# %%
import random
empty = []

# %%
def read_file():
    with open('/home/jhilene/markov/taotc.txt', 'r') as f:
        for line in f:
            #tao = line.strip().lower().strip()
            for word in line.lower().strip().split():
            #empty.append(line.split())
                empty.append(word)
        return empty
        
read_file()
# Out:
# ['tao',
#  'te',
#  'ching',
#  'the',
#  'book',
#  'of',
#  'the',
#  'way',
#  'and',
#  'its',
#  'virtue',
#  '\x01',
#  'the',
#  'way',
#  'cannot',
#  'be',
#  'told.',
#  'the',
#  'name',
#  'cannot',
#  'be',
#  'named.',
#  'the',
#  'nameless',
#  'is',
#  'the',
#  'way',
#  'of',
#  'heaven',
#  'and',
#  'earth.',
#  'the',
#  'named',
#  'is',
#  'matrix',
#  'of',
#  'the',
#  'myriad',
#  'creatures.',
#  'eliminate',
#  'desire',
#  'to',
#  'find',
#  'the',
#  'way.',
#  'embrace',
#  'desire',
#  'to',
#  'know',
#  'the',
#  'creature.',
#  'the',
#  'two',
#  'are',
#  'identical,',
#  'but',
#  'differ',
#  'in',
#  'name',
#  'as',
#  'they',
#  'arise.',
#  'identical',
#  'they',
#  'are',
#  'called',
#  'mysterious,',
#  'mystery',
#  'on',
#  'mystery,',
#  'the',
#  'gate',
#  'of',
#  'many',
#  'secrets.',
#  '\x01',
#  'the',
#  'world',
#  'knows',
#  'beauty',
#  'as',
#  'beauty,',
#  'so',
#  'there',
#  'is',
#  'then',
#  'ugliness.',
#  'the',
#  'world',
#  'knows',
#  'good',
#  'as',
#  'good,',
#  'so',
#  'there',
#  'is',
#  'then',
#  'the',
#  'bad.',
#  'as',
#  'is',
#  'and',
#  'is-not',
#  'create',
#  'each',
#  'other,',
#  'the',
#  'hard',
#  'and',
#  'easy',
#  'define',
#  'each',
#  'other,',
#  'the',
#  'long',
#  'and',
#  'short',
#  'delimit',
#  'each',
#  'other,',
#  'the',
#  'high',
#  'and',
#  'low',
#  'depend',
#  'on',
#  'each',
#  'other,',
#  'voice',
#  'and',
#  'music',
#  'harmonise',
#  'with',
#  'each',
#  'other,',
#  'last',
#  'and',
#  'next',
#  'follow',
#  'each',
#  'other.',
#  'so',
#  'the',
#  'wise',
#  'adhere',
#  'to',
#  'action',
#  'through',
#  'non-action,',
#  'and',
#  'communicate',
#  'the',
#  'teaching',
#  'without',
#  'words.',
#  'from',
#  'the',
#  'way',
#  'come',
#  'the',
#  'myriad',
#  'creatures',
#  'yet',
#  'it',
#  'imposes',
#  'no',
#  'authority.',
#  'it',
#  'gives',
#  'them',
#  'life',
#  'without',
#  'possession.',
#  'it',
#  'benefits',
#  'them',
#  'but',
#  'asks',
#  'no',
#  'thanks.',
#  'it',
#  'does',
#  'its',
#  'work',
#  'but',
#  'claims',
#  'no',
#  'merit.',
#  'because',
#  'it',
#  'claims',
#  'no',
#  'merit',
#  'merit',
#  'is',
#  'never',
#  'lacking',
#  'in',
#  'it.',
#  '\x01',
#  '\x01',
#  "don't",
#  'give',
#  'honours',
#  'to',
#  'the',
#  'worthy,',
#  'protect',
#  'people',
#  'from',
#  'ambition.',
#  "don't",
#  'value',
#  'scarce',
#  'things,',
#  'protect',
#  'the',
#  'people',
#  'from',
#  'envy.',
#  "don't",
#  'show',
#  "what's",
#  'desired,',
#  'keep',
#  'people',
#  'from',
#  'temptation.',
#  'so,',
#  'in',
#  'governing,',
#  'the',
#  'wise',
#  'empty',
#  'the',
#  'mind',
#  'but',
#  'fill',
#  'the',
#  'stomach,',
#  'weaken',
#  'ambition',
#  'but',
#  'strengthen',
#  'the',
#  'bones,',
#  'keep',
#  'things',
#  'free',
#  'of',
#  'desire',
#  'and',
#  'learning,',
#  'so',
#  'the',
#  'clever',
#  'take',
#  'no',
#  'action.',
#  'act',
#  'without',
#  'taking',
#  'action',
#  'and',
#  'things',
#  'will',
#  'be',
#  'in',
#  'order.',
#  '\x01',
#  'the',
#  'way',
#  'is',
#  'full:',
#  'use',
#  "won't",
#  'empty',
#  'it.',
#  'deep',
#  'is',
#  'the',
#  'matrix',
#  'of',
#  'the',
#  'myriad',
#  'creatures.',
#  'blunt',
#  'the',
#  'sharp:',
#  'loosen',
#  'the',
#  'knots:',
#  'dim',
#  'the',
#  'glare:',
#  'follow',
#  'old',
#  'tracks.',
#  'shadowy,',
#  'it',
#  'seems',
#  'hardly',
#  'there.',
#  'i',
#  "don't",
#  'know',
#  'whose',
#  'child',
#  'it',
#  'is.',
#  'it',
#  'seems',
#  'like',
#  'the',
#  'ancestral',
#  'form.',
#  'heaven',
#  'and',
#  'earth',
#  'are',
#  'ruthless,',
#  'trampling',
#  'the',
#  'myriad',
#  'creatures',
#  'like',
#  'straw',
#  'dogs.',
#  'the',
#  'wise',
#  'are',
#  'ruthless,',
#  'considering',
#  'the',
#  'people',
#  'as',
#  'straw',
#  'dogs.',
#  'the',
#  'space',
#  'between',
#  'earth',
#  'and',
#  'heaven,',
#  "isn't",
#  'it',
#  'like',
#  'a',
#  'bellows?',
#  "it's",
#  'empty',
#  'but',
#  'never',
#  'exhausted.',
#  'the',
#  'more',
#  'it',
#  'works',
#  'the',
#  'more',
#  'flows',
#  'out.',
#  'much',
#  'speech',
#  'leads',
#  'in',
#  'the',
#  'end',
#  'to',
#  'silence.',
#  'better',
#  'to',
#  'hold',
#  'fast',
#  'to',
#  'the',
#  'void.',
#  'the',
#  'spirit',
#  'of',
#  'the',
#  'valley',
#  'never',
#  'dies.',
#  'it',
#  'is',
#  'called',
#  'the',
#  'mysterious',
#  'female.',
#  'the',
#  'gate',
#  'of',
#  'the',
#  'mysterious',
#  'female',
#  'is',
#  'called',
#  'the',
#  'root',
#  'of',
#  'heaven',
#  'and',
#  'earth.',
#  'barely',
#  'seen,',
#  'it',
#  'hardly',
#  'seems',
#  'there,',
#  'yet',
#  'use',
#  'will',
#  'never',
#  'exhaust',
#  'it.',
#  '\x01',
#  'heaven',
#  'and',
#  'earth',
#  'endure,',
#  'by',
#  'not',
#  'endowing',
#  'themselves',
#  'with',
#  'life.',
#  'then',
#  'they',
#  'can',
#  'be',
#  'long-lived.',
#  'so',
#  'the',
#  'wise',
#  'place',
#  'self',
#  'last,',
#  'and',
#  'it',
#  'comes',
#  'first,',
#  'call',
#  'it',
#  'other',
#  'than',
#  'themselves,',
#  'and',
#  'it',
#  'persists.',
#  'by',
#  'not',
#  'thinking',
#  'of',
#  'self',
#  'the',
#  'personal',
#  'goal',
#  'is',
#  'achieved.',
#  'the',
#  'highest',
#  'virtue',
#  'is',
#  'like',
#  'water.',
#  'since',
#  'water',
#  'helps',
#  'the',
#  'myriad',
#  'creatures,',
#  'and',
#  'settles,',
#  'without',
#  'contention,',
#  'where',
#  'no',
#  'one',
#  'wishes',
#  'to',
#  'live,',
#  'it',
#  'is',
#  'near',
#  'to',
#  'the',
#  'way.',
#  'in',
#  'a',
#  'house',
#  'position',
#  'matters.',
#  'in',
#  'mental',
#  'quality',
#  'depth',
#  'matters.',
#  'in',
#  'friends',
#  'kindness',
#  'matters.',
#  'in',
#  'speaking',
#  'honesty',
#  'matters.',
#  'in',
#  'government',
#  'order',
#  'matters.',
#  'in',
#  'transactions',
#  'ability',
#  'matters.',
#  'in',
#  'actions',
#  'promptness',
#  'matters.',
#  'by',
#  'not',
#  'contending',
#  'it',
#  'never',
#  'errs.',
#  'rather',
#  'than',
#  'filling',
#  'it',
#  'overfull',
#  'better',
#  'to',
#  'stop',
#  'in',
#  'time.',
#  'sharpen',
#  'it',
#  'to',
#  'a',
#  'point',
#  'the',
#  'edge',
#  "won't",
#  'last',
#  'forever.',
#  'gold',
#  'and',
#  'jade',
#  'may',
#  'fill',
#  'the',
#  'house',
#  'but',
#  'no',
#  'one',
#  'can',
#  'retain',
#  'them.',
#  'boasting',
#  'of',
#  'wealth',
#  'and',
#  'virtue,',
#  'brings',
#  'trouble',
#  'on',
#  'oneself.',
#  'reticence',
#  'when',
#  'the',
#  'job',
#  'is',
#  'done,',
#  'is',
#  'the',
#  'way',
#  'of',
#  'heaven.',
#  'carrying',
#  'your',
#  'spiritual',
#  'body',
#  'on',
#  'your',
#  'head',
#  'can',
#  'you',
#  'embrace',
#  'the',
#  'one',
#  'and',
#  'not',
#  'let',
#  'go?',
#  'concentrating',
#  'the',
#  'breath',
#  'can',
#  'you',
#  'become',
#  'supple',
#  'as',
#  'a',
#  'child?',
#  'can',
#  'you',
#  'polish',
#  'the',
#  'mysterious',
#  'mirror',
#  'and',
#  'leave',
#  'no',
#  'mark?',
#  'can',
#  'you',
#  'love',
#  'the',
#  'people',
#  'and',
#  'rule',
#  'the',
#  'state',
#  'without',
#  'indulging',
#  'in',
#  'action?',
#  'when',
#  'the',
#  'gates',
#  'of',
#  'heaven',
#  'open',
#  'and',
#  'close,',
#  'can',
#  'you',
#  'keep',
#  'to',
#  'the',
#  'female',
#  'role?',
#  'when',
#  'your',
#  'mind',
#  'penetrates',
#  'the',
#  'four',
#  'directions',
#  'are',
#  'you',
#  'able',
#  'to',
#  'know',
#  'nothing?',
#  'it',
#  'gives',
#  'them',
#  'life',
#  'and',
#  'nurtures.',
#  'it',
#  'gives',
#  'them',
#  'life',
#  'without',
#  'possession.',
#  'it',
#  'benefits',
#  'them',
#  'but',
#  'asks',
#  'no',
#  'thanks.',
#  'it',
#  'holds',
#  'but',
#  'imposes',
#  'no',
#  'authority.',
#  'such',
#  'is',
#  'the',
#  'mysterious',
#  'virtue.',
#  'thirty',
#  'spokes',
#  'round',
#  'one',
#  'hub.',
#  'employ',
#  'the',
#  'nothing',
#  'inside',
#  'and',
#  'you',
#  'can',
#  'use',
#  'a',
#  'cart.',
#  'knead',
#  'the',
#  'clay',
#  'to',
#  'make',
#  'a',
#  'pot.',
#  'employ',
#  'the',
#  'nothing',
#  'inside',
#  'and',
#  'you',
#  'can',
#  'use',
#  'a',
#  'pot.',
#  'cut',
#  'out',
#  'doors',
#  'and',
#  'windows.',
#  'employ',
#  'the',
#  'nothing',
#  'inside',
#  'and',
#  'you',
#  'can',
#  'use',
#  'a',
#  'room.',
#  'what',
#  'is',
#  'achieved',
#  'is',
#  'something,',
#  'by',
#  'employing',
#  'nothing',
#  'it',
#  'can',
#  'be',
#  'used.',
#  'the',
#  'five',
#  'colours',
#  'blind',
#  'us.',
#  'the',
#  'five',
#  'notes',
#  'deafen',
#  'us.',
#  'the',
#  'five',
#  'tastes',
#  'deaden',
#  'us.',
#  'pursuing',
#  'and',
#  'catching',
#  'disturb',
#  'the',
#  'mind.',
#  'wanting',
#  'scarce',
#  'things',
#  'delays',
#  'our',
#  'progress.',
#  'so',
#  'the',
#  'wise',
#  'are:',
#  'for',
#  'the',
#  'stomach',
#  'and',
#  'not',
#  'the',
#  'eye.',
#  'taking',
#  'the',
#  'one,',
#  'they',
#  'leave',
#  'the',
#  'other.',
#  'favour',
#  'and',
#  'loss',
#  'of',
#  'it',
#  'both',
#  'disturb',
#  'us.',
#  'rank',
#  'and',
#  'body',
#  'are',
#  'both',
#  'a',
#  'problem.',
#  "what's",
#  'meant',
#  'by',
#  'favour',
#  'and',
#  'loss',
#  'of',
#  'it',
#  'both',
#  'disturb',
#  'us?',
#  'favour',
#  'disturbs',
#  'the',
#  'subject',
#  'when',
#  "it's",
#  'given',
#  'as',
#  'much',
#  'as',
#  'it',
#  'does',
#  'when',
#  "it's",
#  'taken',
#  'away.',
#  "that's",
#  "what's",
#  'meant',
#  'by',
#  'favour',
#  'and',
#  'loss',
#  'of',
#  'it',
#  'both',
#  'disturb',
#  'us.',
#  "what's",
#  'meant',
#  'by',
#  'rank',
#  'and',
#  'body',
#  'are',
#  'both',
#  'a',
#  'problem?',
#  "i've",
#  'problems',
#  'because',
#  'i',
#  'have',
#  'a',
#  'body.',
#  'when',
#  "i've",
#  'no',
#  'body',
#  "where's",
#  'my',
#  'problem?',
#  'who',
#  'values',
#  'the',
#  'body',
#  'even',
#  'more',
#  'than',
#  'the',
#  'empire,',
#  'can',
#  'be',
#  'trusted',
#  'with',
#  'the',
#  'empire.',
#  'who',
#  'loves',
#  'the',
#  'body',
#  'even',
#  'more',
#  'than',
#  'the',
#  'empire,',
#  'can',
#  'be',
#  'a',
#  'custodian',
#  'of',
#  'the',
#  'empire.',
#  'what',
#  'cannot',
#  'be',
#  'seen',
#  'is',
#  'called',
#  'indistinguishable.',
#  'what',
#  'cannot',
#  'be',
#  'heard',
#  'is',
#  'called',
#  'indistinct.',
#  'what',
#  'cannot',
#  'be',
#  'touched',
#  'is',
#  'called',
#  'indefinite.',
#  'the',
#  'three',
#  "can't",
#  'be',
#  'comprehended',
#  'so',
#  "they're",
#  'confused',
#  'and',
#  'considered',
#  'one.',
#  'its',
#  'surface',
#  'is',
#  'not',
#  'bright.',
#  'its',
#  'depths',
#  'are',
#  'not',
#  'obscured.',
#  'dimly',
#  'seen',
#  'it',
#  "can't",
#  'be',
#  'named',
#  'so',
#  'returns',
#  'to',
#  'the',
#  'insubstantial.',
#  'this',
#  'is',
#  'the',
#  'shapeless',
#  'shape,',
#  'the',
#  'form',
#  'without',
#  'substance.',
#  'this',
#  'is',
#  'called',
#  'blurred',
#  'and',
#  'shadowy.',
#  'approach',
#  'it',
#  'you',
#  "can't",
#  'see',
#  'its',
#  'face.',
#  'follow',
#  'it',
#  'you',
#  "can't",
#  'see',
#  'its',
#  'back.',
#  'hold',
#  'fast',
#  'to',
#  'the',
#  'ancient',
#  'way',
#  'in',
#  'order',
#  'to',
#  'control',
#  'the',
#  'present.',
#  'knowing',
#  'the',
#  'source',
#  'of',
#  'the',
#  'ancient,',
#  'is',
#  'the',
#  'thread',
#  ...]

# %%
master_dict = {}
total = 0
for i in range(len(empty)-1):
    j = i + 1
    t_w = empty[i]
    j_w = empty[j]
    
    if t_w not in master_dict:
        master_dict[t_w]= []
        
    w_d = master_dict[t_w]
    w_d.append(j_w)
         
  
print master_dict
# Out:
# {'\x00': ['\x00', '\x00', '\x00', '\x00', '\x00', '\x00', '\x00\x0e\x00'], 'indefinite.': ['the'], 'indistinguishable.': ['what'], 'all': ['they', 'are', 'morning,', 'day.', 'day', 'beings', 'honour', 'things', 'day', 'the', 'the', 'the', 'things', 'my', 'contention'], 'four': ['directions', 'things'], 'ocean,': ['like'], 'behind.': ['so'], 'hate': ['the'], 'inch,': ['i'], 'overcome.': ['when'], 'whose': ['child'], 'governing,': ['the'], 'teaching': ['without'], 'nourishes': ['them,'], 'otherwise.': ['they'], 'glorious,': ['those'], 'compassion': ['you'], 'rashly': ['taking', 'taking'], 'rise': ['together'], 'returning.': ['so'], 'every': ['being.'], 'govern': ['they', 'the', "it's", 'a'], 'overcomes': ['cold.', 'heat.', 'the', 'easily', 'the', 'the'], 'wagons': ['let'], 'transformed,': ['they'], 'encounter': ['tigers', 'each'], 'transformed.': ['if,'], 'disturb': ['the', 'us.', 'us?', 'us.'], 'problems,': ["you'll"], 'present.': ['knowing'], 'shows': ['no'], 'clothes': ['the'], 'force': ['they', 'without'], 'contention,': ['where', 'replies'], 'me.': ['those'], 'likely': ['to'], 'others.': ['i', 'shine'], 'even': ['more', 'more', 'heaven', 'if', 'the'], 'employ': ['the', 'the', 'the', 'reticence,', 'them.'], 'hide': ['priceless'], 'nature,': ['and'], 'nature.': ['so'], 'understood.': ['because'], 'rest.': ["it's"], 'above': ['to'], 'rest,': ['how'], 'net': ['of'], 'rope,': ["they'll"], 'ulterior': ['motives.', 'motives.'], 'never': ['lacking', 'exhausted.', 'dies.', 'exhaust', 'errs.', 'lost.', 'control', 'regards', 'control', 'encounter', 'harmed', 'try', 'resents', 'angry.', 'encounters', 'harms'], 'faults.': ['expert'], 'here': ['and'], 'ching': ['the'], 'governing': ['the', 'the', 'the'], 'humility': ['is'], 'through.': ['if'], 'dry': ['and'], 'substance': ['is', 'and'], 'leaves': ['no'], 'turbulent.': ['so'], 'light.': ['this'], 'far-off': ['implies', 'places.'], 'military': ['matters'], "i'm": ['different'], 'punishment': ['of'], 'perfecting.': ['the'], 'secure': ['behind'], 'straw': ['dogs.', 'dogs.'], 'gentleman,': ['in'], 'gentleman.': ['when'], 'brought': ['achievement,'], 'war,': ['and'], 'starving.': ["it's", 'the'], 'female.': ['the'], 'greatness.': ['rash'], 'opponents': ['encounter'], 'would': ['submit', 'unite', 'fall.', 'be', 'make'], 'army': ['bad'], 'right?': ['the'], "world's": ['relation'], 'music': ['harmonise', 'and'], 'therefore': ['apparent,', 'known,', 'of', 'align', 'not', 'not', 'not', 'the'], 'right.': ['mourning', 'i'], 'until': ['one'], 'used.': ['the'], 'mother!': ['great'], 'breathe': ['easily,', 'hard,'], 'dry.': ['if'], 'guest.': ["it's"], 'brings': ['trouble'], 'guest,': ['fluid,'], 'sorrow.': ['when'], 'reign': ['in'], 'aware': ['of', 'of'], 'summon,': ['obeys'], 'leans': ['on'], 'tying': ['is'], 'separates': ['good'], 'aligned': ['with', 'with', 'with'], 'must': ['respect', 'rest,', 'have', 'have'], 'me': ["that's", "that's", "it's", "that's", 'all', 'are'], 'join': ['with'], 'work': ['but', 'is', 'but', 'but'], 'worn': ['away'], 'resents': ['doing'], 'arm,': ['meeting'], 'my': ['problem?', 'best', "mind's", 'basic', 'way', 'treasure.', 'words'], '\x01': ['the', 'the', '\x01', "don't", 'the', 'heaven', 'the', 'the', 'great', 'when', 'you', 'in', 'pursuing', 'when', 'the', 'true'], 'loosen': ['the'], 'constant.': ['knowing', 'if', 'to'], 'give': ['honours', 'to', 'to', 'to', 'it'], 'obstruction.': ['therefore'], 'involve': ['awing'], '\x00\x1d\x00': [' ...

# %%
import random
w = 'a'
string = ' '
for i in range(6):
    string+= (w)
    string+=(' ')
    w = random.choice(master_dict[w])
    if w == '\x00':
        break
print string
# Out:
#  a tower nine stories high rises
